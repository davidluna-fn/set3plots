# %%
pip install git+https://github.com/davidluna-fn/set3plots.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/davidluna-fn/set3plots.git to /tmp/pip-req-build-h3aaq0kd
#   Running command git clone --filter=blob:none --quiet https://github.com/davidluna-fn/set3plots.git /tmp/pip-req-build-h3aaq0kd
#   Resolved https://github.com/davidluna-fn/set3plots.git to commit 78c5764c9420b0eec06f0283ac3df015f6347d73
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for git+https://github.com/davidluna-fn/set3plots.git.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'wheel'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl


#mpl.get_configdir()
plt.style.use('set3dark')

x1 = np.linspace(0, 1, 100)
y1 = np.sin(2 * np.pi * x1)
y2 = np.cos(2 * np.pi * x1)

plt.figure(figsize=(15,7))

plt.plot(x1, y1, label='sin')
plt.plot(x1, y2, label='cos')
plt.legend()
plt.grid()

plt.title('$\sin{\\alpha}$ and $\cos{\\beta}$')
plt.ylabel('Amplitude [V]')
plt.xlabel('Time [s]')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl


#mpl.get_configdir()
plt.style.use('set3white')

x1 = np.linspace(0, 1, 100)
y1 = np.sin(2 * np.pi * x1)
y2 = np.cos(2 * np.pi * x1)

plt.figure(figsize=(15,7))

plt.plot(x1, y1, label='sin')
plt.plot(x1, y2, label='cos')
plt.legend()
plt.grid()

plt.title('$\sin{\\alpha}$ and $\cos{\\beta}$')
plt.ylabel('Amplitude [V]')
plt.xlabel('Time [s]')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/style/core.py:127, in use(style)
#     126 try:
# --> 127     rc = rc_params_from_file(style, use_default_template=False)
#     128     _apply_style(rc)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:856, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     842 """
#     843 Construct a `RcParams` from file *fname*.
#     844
#    (...)
#     854     parameters specified in the file. (Useful for updating dicts.)
#     855 """
# --> 856 config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     858 if not use_default_template:
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:782, in _rc_params_in_file(fname, transform, fail_on_error)
#     781 rc_temp = {}
# --> 782 with _open_file_or_url(fname) as fd:
# ...
